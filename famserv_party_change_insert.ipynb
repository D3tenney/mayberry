# %%
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv
import s3fs
import pandas as pd

load_dotenv(override=True)

# DATABASE CONNECTION
PG_USER = os.environ.get("PG_USER")
PG_PASS = os.environ.get("PG_PASS")
PG_HOST = os.environ.get("PG_HOST")
PG_DB = os.environ.get("PG_DB")
PG_PORT = os.environ.get("PG_PORT")

conn_string = "postgresql://{0}:{1}@{2}:{3}/{4}".format(
    PG_USER, PG_PASS, PG_HOST, PG_PORT, PG_DB)
engine = create_engine(conn_string)
conn = engine.connect()

# %%
for chunk in pd.read_csv('s3://dl.ncsbe.gov/data/PartyChange/2020_party_change_list.csv', chunksize=10000):
    chunk = chunk[['voter_reg_num', 'change_dt', 'party_from', 'party_to', 'county_id']]
    chunk.to_sql('party_change',
                 if_exists='append',
                 index=False,
                 method='multi',
                 chunksize=2000,
                 con=conn)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# c:\users\d3ten\documents\gitprojects\nc_voter\venv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# c:\users\d3ten\documents\gitprojects\nc_voter\venv\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# UniqueViolation: duplicate key value violates unique constraint "party_change_pkey"
# DETAIL:  Key (voter_reg_num, change_dt)=(9191075, 2020-01-14) already exists.
#
#
# ...

# %%
df = pd.read_csv('s3://dl.ncsbe.gov/data/PartyChange/2020_party_change_list.csv')

df[df['voter_reg_num'] == 9191075]
# Out:
#     county_id  county_name  year_change  voter_reg_num party_from party_to  \
# 24          1     ALAMANCE         2020        9191075        UNA      DEM
# 25          1     ALAMANCE         2020        9191075        DEM      UNA
#
#      change_dt
# 24  01/14/2020
# 25  01/14/2020

# %%
df['is_dup'] = df.duplicated(subset=['voter_reg_num', 'change_dt'])

dups = df[df['is_dup'] == True]
dups.shape
# Out:
# (91, 8)

# %%
dups.sort_values('voter_reg_num').head()
# Out:
#        county_id  county_name  year_change  voter_reg_num party_from party_to  \
# 18512         96        WAYNE         2020           3659        DEM      REP
# 14221         80        ROWAN         2020           5907        DEM      REP
# 697            9       BLADEN         2020           6547        UNA      REP
# 744            9       BLADEN         2020          10366        UNA      REP
# 7961          43      HARNETT         2020          12962        DEM      REP
#
#         change_dt  is_dup
# 18512  01/17/2020    True
# 14221  01/22/2020    True
# 697    01/28/2020    True
# 744    01/22/2020    True
# 7961   01/31/2020    True

# %%
df[df['voter_reg_num'].isin(dups['voter_reg_num'].tolist())].sort_values('voter_reg_num').head()
# Out:
#        county_id  county_name  year_change  voter_reg_num party_from party_to  \
# 18512         96        WAYNE         2020           3659        DEM      REP
# 13079         71       PENDER         2020           3659        DEM      REP
# 14221         80        ROWAN         2020           5907        DEM      REP
# 2077          12        BURKE         2020           5907        UNA      REP
# 696            9       BLADEN         2020           6547        DEM      UNA
#
#         change_dt  is_dup
# 18512  01/17/2020    True
# 13079  01/17/2020   False
# 14221  01/22/2020    True
# 2077   01/22/2020   False
# 696    01/28/2020   False

# %%
del df

# %%
conn.close()
engine.dispose()1`
# Out:
#   File "<ipython-input-19-031099285471>", line 2
#     engine.dispose()1`
#                     ^
# SyntaxError: invalid syntax
